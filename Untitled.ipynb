# %% [markdown]
# # Visualize Training

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !python train --num_epoch 10000

# %%
# !python generate_text.py --text_seed "Imagine how bad this book could be. The reality will surprise you:" #--stochastic
# Out:
# Selected device: cuda
# Loading model from: model/params
# Existing embedding matrix loaded
#
# Imagine how bad this book could be. The reality will surprise you: the the the the the the the the the the the the the the the the the the the the the the the the the

# %%
loss_history = pd.read_csv("model/params/loss_history.txt", sep="\t", header=0)
plt.figure()
loss_history["val_loss"].plot(), loss_history["train_loss"].plot()
plt.grid()
plt.legend(["Validation", "Train"])
plt.xlabel("Epoch"), plt.ylabel("Cross Entropy")
plt.show()
