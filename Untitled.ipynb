# %% [markdown]
# # Visualize Training

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !python train --num_epoch 10000

# %%
# !python generate_text.py
# Out:
# Error: mkl-service + Intel(R) MKL: MKL_THREADING_LAYER=INTEL is incompatible with libgomp.so.1 library.
# 	Try to import numpy first or set the threading layer accordingly. Set MKL_SERVICE_FORCE_INTEL to force it.

# %%
loss_history = pd.read_csv("model/params/loss_history.txt", sep="\t", header=0)
plt.figure()
loss_history["val_loss"].plot(), loss_history["train_loss"].plot()
plt.grid()
plt.legend(["Validation", "Train"])
plt.xlabel("Epoch"), plt.ylabel("Cross Entropy")
#plt.xlim((0, 350))
#plt.vlines(100, 2, 8.5)
plt.savefig("Loss_5000.png", pdi=300)
plt.show()
