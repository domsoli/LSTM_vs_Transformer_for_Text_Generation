# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
loss_history = pd.read_csv("model/params/loss_history.txt", sep="\t", header=0)
plt.figure()
loss_history["train_loss"].plot()
loss_history["val_loss"].plot()
plt.grid()
plt.legend(["Train", "Validation"])
plt.xlabel("Epoch")
plt.ylabel("Cross Entropy")
# Out:
# Text(0, 0.5, 'Cross Entropy')

# %%
# lr 3e-3
# wd 0
# do 0.2
loss_history = pd.read_csv("model/params/loss_history.txt", sep="\t", header=0)
plt.figure()
loss_history["train_loss"].plot()
loss_history["val_loss"].plot()
plt.grid()
plt.legend(["Train", "Validation"])
plt.xlabel("Epoch")
plt.ylabel("Cross Entropy")
# Out:
# Text(0, 0.5, 'Cross Entropy')

# %%
# lr 1e-3
# wd 1e-4
# do 0.35
loss_history = pd.read_csv("model/params/loss_history.txt", sep="\t", header=0)
plt.figure()
loss_history["train_loss"].plot()
loss_history["val_loss"].plot()
plt.grid()
plt.legend(["Train", "Validation"])
plt.xlabel("Epoch")
plt.ylabel("Cross Entropy")
# Out:
# Text(0, 0.5, 'Cross Entropy')

# %%
# lr 1e-4
# wd 1e-6
# do 0.4
loss_history = pd.read_csv("model/params/loss_history.txt", sep="\t", header=0)
plt.figure()
loss_history["train_loss"].plot()
loss_history["val_loss"].plot()
plt.grid()
plt.legend(["Train", "Validation"])
plt.xlabel("Epoch")
plt.ylabel("Cross Entropy")
plt.show()

# %%
# lr 1e-3
# wd 1e-4
# do 0.4
loss_history = pd.read_csv("model/params/loss_history.txt", sep="\t", header=0)
plt.figure()
loss_history["train_loss"].plot()
loss_history["val_loss"].plot()
plt.grid()
plt.legend(["Train", "Validation"])
plt.xlabel("Epoch")
plt.ylabel("Cross Entropy")
plt.show()

# %% [markdown]
# ## Terzo layer aggiunto! (Sempre 2^9 neuroni)

# %%
# lr 1e-3
# wd 1e-4
# do 0.3
loss_history = pd.read_csv("model/params/loss_history.txt", sep="\t", header=0)
plt.figure()
loss_history["train_loss"].plot()
loss_history["val_loss"].plot()
plt.grid()
plt.legend(["Train", "Validation"])
plt.xlabel("Epoch")
plt.ylabel("Cross Entropy")
plt.show()

# %%
# lr 1e-3
# wd 1e-4
# do 0.3
# 4 layer with 2^6 neurons
loss_history = pd.read_csv("model/params/loss_history.txt", sep="\t", header=0)
plt.figure()
loss_history["train_loss"].plot()
loss_history["val_loss"].plot()
plt.grid()
plt.legend(["Train", "Validation"])
plt.xlabel("Epoch")
plt.ylabel("Cross Entropy")
plt.show()

# %%
# lr 5e-3
# wd 0
# do 0.4
# 3 layer with 2^9 neurons
loss_history = pd.read_csv("model/params/loss_history.txt", sep="\t", header=0)
plt.figure()
loss_history["train_loss"].plot()
loss_history["val_loss"].plot()
plt.grid()
plt.legend(["Train", "Validation"])
plt.xlabel("Epoch")
plt.ylabel("Cross Entropy")
plt.show()

# %%
# lr 1e-3
# wd 1e-6
# do 0.3
# 3 layer with 2^9 neurons
loss_history = pd.read_csv("model/params/loss_history.txt", sep="\t", header=0)
plt.figure()
loss_history["train_loss"].plot()
loss_history["val_loss"].plot()
plt.grid()
plt.legend(["Train", "Validation"])
plt.xlabel("Epoch")
plt.ylabel("Cross Entropy")
plt.show()

# %% [markdown]
# ## Minimum sentence lenght increased to 25, batch size to 25
# Dataset lenght dropped to 1971

# %%
# lr 1e-3
# wd 1e-6
# do 0.3
# 3 layer with 2^9 neurons
loss_history = pd.read_csv("model/params/loss_history.txt", sep="\t", header=0)
plt.figure()
loss_history["train_loss"].plot()
loss_history["val_loss"].plot()
plt.grid()
plt.legend(["Train", "Validation"])
plt.xlabel("Epoch")
plt.ylabel("Cross Entropy")
plt.show()

# %% [markdown]
# ### Back to 2 layers

# %%
# lr 1e-3
# wd 1e-4
# do 0.3
# 2 layer with 2^9 neurons
loss_history = pd.read_csv("model/params/loss_history.txt", sep="\t", header=0)
plt.figure()
loss_history["train_loss"].plot()
loss_history["val_loss"].plot()
plt.grid()
plt.legend(["Train", "Validation"])
plt.xlabel("Epoch")
plt.ylabel("Cross Entropy")
plt.show()

# %% [markdown]
# # Il ritorno del re!

# %%
# lr 1e-3
# wd 1e-4
# do 0.3
# 2 layer with 2^9 neurons
loss_history = pd.read_csv("model/params/loss_history.txt", sep="\t", header=0)
plt.figure()
loss_history["train_loss"].plot()
loss_history["val_loss"].plot()
plt.grid()
plt.legend(["Train", "Validation"])
plt.xlabel("Epoch")
plt.ylabel("Cross Entropy")
plt.show()

# %%
# lr 1e-3
# wd 1e-4
# do 0.3
# 2 layer with 2^9 neurons
# batchsize 100
loss_history = pd.read_csv("model/params/loss_history.txt", sep="\t", header=0)
plt.figure()
loss_history["val_loss"].plot()
loss_history["train_loss"].plot()
plt.grid()
plt.legend(["Validation", "Train"])
plt.xlabel("Epoch")
plt.ylabel("Cross Entropy")
plt.show()

# %%
# lr 1e-3
# wd 1e-6
# do 0.2
# 3 layer with 2^9 neurons
# batchsize 100
loss_history = pd.read_csv("model/params/loss_history.txt", sep="\t", header=0)
plt.figure()
loss_history["val_loss"].plot()
loss_history["train_loss"].plot()
plt.grid()
plt.legend(["Validation", "Train"])
plt.xlabel("Epoch")
plt.ylabel("Cross Entropy")
plt.show()

# %%
# lr 1e-3
# wd 1e-6
# do 0.3
# 5 layer with 2^8 neurons
# batchsize 100
loss_history = pd.read_csv("model/params/loss_history.txt", sep="\t", header=0)
plt.figure()
loss_history["val_loss"].plot()
loss_history["train_loss"].plot()
plt.grid()
plt.legend(["Validation", "Train"])
plt.xlabel("Epoch")
plt.ylabel("Cross Entropy")
plt.xlim((0,2000))
plt.show()
